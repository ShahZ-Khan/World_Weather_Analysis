# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates: 
    # Use the citipy module to identify the nearest city to the current coordinate
    city =  city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 779

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
weather_api_key
# Out:
# 'fadf6125de4a9b6c81535d673451c2b5'

# %%
# Assemble the OpenWeatherMap's API call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6218f3b10e6b4e30869dcf73a31f08a1"
url =  "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fadf6125de4a9b6c81535d673451c2b5"
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fadf6125de4a9b6c81535d673451c2b5

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | kyrylivka
# Processing Record 4 of Set 1 | naryan-mar
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | husavik
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | flinders
# Processing Record 10 of Set 1 | capitan bado
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | itumbiara
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | maniitsoq
# Processing Record 19 of Set 1 | napasar
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | worthington
# Processing Record 24 of Set 1 | linxia
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | trabzon
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | kota kinabalu
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | banda aceh
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | havelock
# Processing Record 37 of Set 1 | aksarka
# Processing Record 38 of Set 1 | lata
# Processing Record 39 of Set 1 | marzuq
# Processing Record 40 of Set 1 | shimoda
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | arlit
# Processing Record 44 of Set 1 | shache
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | reconquista
# Processing Record 50 of Set 1 | roald
# Processing Record 0 of Set 2 | bouca
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | saint-joseph
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | fairbanks
# Processing Record 5 of Set 2 | chinhoyi
# Processing Record 6 of Set 2 | kamenka
# Processing Record 7 of Set 2 | shaunavon
# Processing Record 8 of Set 2 | mehamn
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | priargunsk
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | ndele
# Processing Record 14 of Set 2 | shirokiy
# Processing Record 15 of Set 2 | tahta
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | velikie luki
# City not found. Skipping...
# Processing Record 20 of Set 2 | monroe
# Processing Record 21 of Set 2 | lasa
# Processing Record 22 of Set 2 | merauke
# Processing Record 23 of Set 2 | maltahohe
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | yerbogachen
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | asyut
# Processing Record 28 of Set 2 | dingle
# Processing Record 29 of Set 2 | constitucion
# Processing Record 30 of Set 2 | kadnikov
# Processing Record 31 of Set 2 | broome
# Processing Record 32 of Set 2 | tomatlan
# Processing Record 33 of Set 2 | buchanan
# Processing Record 34 of Set 2 | nagai
# Processing Record 35 of Set 2 | wum
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | puerto madryn
# Processing Record 40 of Set 2 | qidong
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | mayakonda
# Processing Record 43 of Set 2 | mao
# Processing Record 44 of Set 2 | valdez
# Processing Record 45 of Set 2 | prainha
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | cachira
# Processing Record 0 of Set 3 | fukue
# Processing Record 1 of Set 3 | sonqor
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | coahuayana
# Processing Record 4 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | balakhonovskoye
# Processing Record 7 of Set 3 | chiknayakanhalli
# Processing Record 8 of Set 3 | seaford
# Processing Record 9 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 3 | dhaka
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | rawah
# Processing Record 13 of Set 3 | la ronge
# Processing Record 14 of Set 3 | karasjok
# Processing Record 15 of Set 3 | rawson
# Processing Record 16 of Set 3 | meulaboh
# Processing Record 17 of Set 3 | mitsamiouli
# Processing Record 18 of Set 3 | madras
# Processing Record 19 of Set 3 | plouzane
# Processing Record 20 of Set 3 | mahajanga
# Processing Record 21 of Set 3 | sioux lookout
# Processing Record 22 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | cockburn town
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | henties bay
# Processing Record 31 of Set 3 | katobu
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | bajil
# Processing Record 34 of Set 3 | vao
# Processing Record 35 of Set 3 | roebourne
# Processing Record 36 of Set 3 | alexandria
# Processing Record 37 of Set 3 | susanville
# Processing Record 38 of Set 3 | iracoubo
# Processing Record 39 of Set 3 | guerrero negro
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | pangai
# Processing Record 43 of Set 3 | verkhnevilyuysk
# Processing Record 44 of Set 3 | bolotnoye
# Processing Record 45 of Set 3 | port hawkesbury
# Processing Record 46 of Set 3 | umm lajj
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | barrow
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 0 of Set 4 | nara
# Processing Record 1 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 4 | takhtamukay
# Processing Record 3 of Set 4 | vestmannaeyjar
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | te anau
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | columbus
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | corato
# Processing Record 11 of Set 4 | hobyo
# Processing Record 12 of Set 4 | storforshei
# Processing Record 13 of Set 4 | morant bay
# Processing Record 14 of Set 4 | abapo
# Processing Record 15 of Set 4 | mariveles
# Processing Record 16 of Set 4 | charters towers
# Processing Record 17 of Set 4 | manta
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | velyka lepetykha
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | barcelos
# Processing Record 23 of Set 4 | jaguaribe
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | uige
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | swan hill
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | charlestown
# Processing Record 31 of Set 4 | lipari
# Processing Record 32 of Set 4 | cape town
# Processing Record 33 of Set 4 | waipawa
# Processing Record 34 of Set 4 | garissa
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | kuandian
# Processing Record 37 of Set 4 | tabou
# Processing Record 38 of Set 4 | manokwari
# Processing Record 39 of Set 4 | malpe
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | vestmanna
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | kieta
# Processing Record 44 of Set 4 | burica
# City not found. Skipping...
# Processing Record 45 of Set 4 | kuito
# Processing Record 46 of Set 4 | lac du bonnet
# Processing Record 47 of Set 4 | tura
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | bull savanna
# Processing Record 0 of Set 5 | bama
# Processing Record 1 of Set 5 | lorengau
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | coria
# Processing Record 4 of Set 5 | antalaha
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | abu kamal
# Processing Record 7 of Set 5 | russell
# Processing Record 8 of Set 5 | shorapani
# Processing Record 9 of Set 5 | breves
# Processing Record 10 of Set 5 | comodoro rivadavia
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | benguela
# Processing Record 13 of Set 5 | caravelas
# Processing Record 14 of Set 5 | basco
# Processing Record 15 of Set 5 | kaabong
# Processing Record 16 of Set 5 | inuvik
# Processing Record 17 of Set 5 | gemena
# Processing Record 18 of Set 5 | estelle
# Processing Record 19 of Set 5 | paita
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | sirjan
# Processing Record 23 of Set 5 | coro
# Processing Record 24 of Set 5 | tabuk
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | boa vista
# Processing Record 27 of Set 5 | shingu
# Processing Record 28 of Set 5 | paraopeba
# Processing Record 29 of Set 5 | venado tuerto
# Processing Record 30 of Set 5 | magrath
# Processing Record 31 of Set 5 | moose factory
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | qinzhou
# Processing Record 35 of Set 5 | inzhavino
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | omboue
# Processing Record 38 of Set 5 | luxor
# Processing Record 39 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | point pedro
# Processing Record 41 of Set 5 | usinsk
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | wasilla
# Processing Record 44 of Set 5 | namibe
# Processing Record 45 of Set 5 | peterhead
# Processing Record 46 of Set 5 | amiens
# Processing Record 47 of Set 5 | necochea
# Processing Record 48 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 5 | ugoofaaru
# Processing Record 0 of Set 6 | camacha
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | snegiri
# Processing Record 3 of Set 6 | port macquarie
# Processing Record 4 of Set 6 | pisco
# Processing Record 5 of Set 6 | svelgen
# Processing Record 6 of Set 6 | cap malheureux
# Processing Record 7 of Set 6 | gisenyi
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | juripiranga
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | bilma
# Processing Record 14 of Set 6 | kroya
# Processing Record 15 of Set 6 | sidney
# Processing Record 16 of Set 6 | shkotovo-22
# City not found. Skipping...
# Processing Record 17 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | derventa
# Processing Record 21 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | houma
# Processing Record 24 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 6 | astoria
# Processing Record 26 of Set 6 | luanda
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | zambezi
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | dzaoudzi
# Processing Record 31 of Set 6 | dong hoi
# Processing Record 32 of Set 6 | trofors
# Processing Record 33 of Set 6 | aswan
# Processing Record 34 of Set 6 | loding
# Processing Record 35 of Set 6 | richards bay
# Processing Record 36 of Set 6 | tahe
# Processing Record 37 of Set 6 | gondanglegi
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | lewisville
# Processing Record 40 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 6 | rudnogorsk
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | shihezi
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | bambous virieux
# Processing Record 46 of Set 6 | tigil
# Processing Record 47 of Set 6 | menongue
# Processing Record 48 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 6 | westport
# Processing Record 0 of Set 7 | komsomolskiy
# Processing Record 1 of Set 7 | san jose del palmar
# Processing Record 2 of Set 7 | lewiston
# Processing Record 3 of Set 7 | emerald
# Processing Record 4 of Set 7 | saint george
# Processing Record 5 of Set 7 | camopi
# Processing Record 6 of Set 7 | pedasi
# Processing Record 7 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 7 | eirunepe
# Processing Record 9 of Set 7 | ferme-neuve
# Processing Record 10 of Set 7 | lerik
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | atbasar
# Processing Record 13 of Set 7 | pagudpud
# Processing Record 14 of Set 7 | gueret
# Processing Record 15 of Set 7 | tual
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | morros
# Processing Record 18 of Set 7 | channel-port aux basques
# Processing Record 19 of Set 7 | thompson
# Processing Record 20 of Set 7 | mnogovershinnyy
# Processing Record 21 of Set 7 | college
# Processing Record 22 of Set 7 | touros
# Processing Record 23 of Set 7 | puerto suarez
# Processing Record 24 of Set 7 | tiarei
# Processing Record 25 of Set 7 | dakar
# Processing Record 26 of Set 7 | malkangiri
# Processing Record 27 of Set 7 | kedrovyy
# Processing Record 28 of Set 7 | honiara
# Processing Record 29 of Set 7 | nanchang
# Processing Record 30 of Set 7 | lengshuitan
# Processing Record 31 of Set 7 | ferkessedougou
# Processing Record 32 of Set 7 | mahishadal
# Processing Record 33 of Set 7 | palmer
# Processing Record 34 of Set 7 | lebork
# Processing Record 35 of Set 7 | chik
# Processing Record 36 of Set 7 | maunabo
# Processing Record 37 of Set 7 | ust-tsilma
# Processing Record 38 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | ibiruba
# Processing Record 40 of Set 7 | irece
# Processing Record 41 of Set 7 | vila do maio
# Processing Record 42 of Set 7 | whitehorse
# Processing Record 43 of Set 7 | dukat
# Processing Record 44 of Set 7 | lucapa
# Processing Record 45 of Set 7 | huilong
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | ndola
# Processing Record 48 of Set 7 | palasa
# Processing Record 49 of Set 7 | duekoue
# Processing Record 0 of Set 8 | kavaratti
# Processing Record 1 of Set 8 | kahului
# Processing Record 2 of Set 8 | adrar
# Processing Record 3 of Set 8 | bartica
# Processing Record 4 of Set 8 | yumen
# Processing Record 5 of Set 8 | taywarah
# Processing Record 6 of Set 8 | polyarnyy
# Processing Record 7 of Set 8 | aanekoski
# Processing Record 8 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 8 | gambela
# Processing Record 10 of Set 8 | waingapu
# Processing Record 11 of Set 8 | lukovetskiy
# Processing Record 12 of Set 8 | pangody
# Processing Record 13 of Set 8 | thinadhoo
# Processing Record 14 of Set 8 | kentau
# Processing Record 15 of Set 8 | brae
# Processing Record 16 of Set 8 | orocue
# Processing Record 17 of Set 8 | collie
# Processing Record 18 of Set 8 | quatre cocos
# Processing Record 19 of Set 8 | mahebourg
# Processing Record 20 of Set 8 | anjozorobe
# Processing Record 21 of Set 8 | maieru
# Processing Record 22 of Set 8 | shahi
# Processing Record 23 of Set 8 | bubaque
# Processing Record 24 of Set 8 | clyde river
# Processing Record 25 of Set 8 | naantali
# Processing Record 26 of Set 8 | araouane
# Processing Record 27 of Set 8 | vardo
# Processing Record 28 of Set 8 | kelo
# Processing Record 29 of Set 8 | olinda
# Processing Record 30 of Set 8 | winnemucca
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | bud
# Processing Record 33 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 8 | saint anthony
# Processing Record 35 of Set 8 | turukhansk
# Processing Record 36 of Set 8 | sao joao da barra
# Processing Record 37 of Set 8 | marsa matruh
# Processing Record 38 of Set 8 | eureka
# Processing Record 39 of Set 8 | mandalgovi
# Processing Record 40 of Set 8 | finschhafen
# Processing Record 41 of Set 8 | aitape
# Processing Record 42 of Set 8 | tautira
# Processing Record 43 of Set 8 | carlyle
# Processing Record 44 of Set 8 | salalah
# Processing Record 45 of Set 8 | puli
# Processing Record 46 of Set 8 | ikot ekpene
# Processing Record 47 of Set 8 | monrovia
# Processing Record 48 of Set 8 | ewo
# Processing Record 49 of Set 8 | buldana
# Processing Record 0 of Set 9 | kabare
# Processing Record 1 of Set 9 | sitka
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | avarua
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | fagersta
# Processing Record 6 of Set 9 | victoria
# Processing Record 7 of Set 9 | virginia beach
# Processing Record 8 of Set 9 | kaseda
# Processing Record 9 of Set 9 | shubarkuduk
# Processing Record 10 of Set 9 | wright
# Processing Record 11 of Set 9 | ituverava
# Processing Record 12 of Set 9 | luba
# Processing Record 13 of Set 9 | mani
# Processing Record 14 of Set 9 | itacoatiara
# Processing Record 15 of Set 9 | warwick
# Processing Record 16 of Set 9 | asau
# Processing Record 17 of Set 9 | west bay
# Processing Record 18 of Set 9 | kabo
# Processing Record 19 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint-georges
# Processing Record 21 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 9 | salinas
# Processing Record 23 of Set 9 | naze
# Processing Record 24 of Set 9 | umea
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | ostersund
# Processing Record 27 of Set 9 | sisimiut
# Processing Record 28 of Set 9 | ishinomaki
# Processing Record 29 of Set 9 | presidencia roque saenz pena
# Processing Record 30 of Set 9 | ladario
# Processing Record 31 of Set 9 | makakilo city
# Processing Record 32 of Set 9 | moussoro
# Processing Record 33 of Set 9 | janakpur road
# City not found. Skipping...
# Processing Record 34 of Set 9 | bodaybo
# Processing Record 35 of Set 9 | kudahuvadhoo
# Processing Record 36 of Set 9 | zacualpan
# Processing Record 37 of Set 9 | isangel
# Processing Record 38 of Set 9 | basoko
# Processing Record 39 of Set 9 | sarangani
# Processing Record 40 of Set 9 | camalu
# Processing Record 41 of Set 9 | dinard
# Processing Record 42 of Set 9 | bilibino
# Processing Record 43 of Set 9 | bure
# Processing Record 44 of Set 9 | lagdo
# Processing Record 45 of Set 9 | snezhnogorsk
# Processing Record 46 of Set 9 | chopda
# Processing Record 47 of Set 9 | ilulissat
# Processing Record 48 of Set 9 | bertoua
# Processing Record 49 of Set 9 | yangambi
# Processing Record 0 of Set 10 | aloleng
# Processing Record 1 of Set 10 | banyumas
# Processing Record 2 of Set 10 | dowa
# Processing Record 3 of Set 10 | bahar
# Processing Record 4 of Set 10 | krasnoselkup
# Processing Record 5 of Set 10 | havoysund
# Processing Record 6 of Set 10 | les cayes
# Processing Record 7 of Set 10 | salinopolis
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | novorudnyy
# Processing Record 10 of Set 10 | ariquemes
# Processing Record 11 of Set 10 | mahon
# Processing Record 12 of Set 10 | san pedro
# Processing Record 13 of Set 10 | mujiayingzi
# Processing Record 14 of Set 10 | muscat
# Processing Record 15 of Set 10 | perth
# Processing Record 16 of Set 10 | moron
# Processing Record 17 of Set 10 | talalayivka
# Processing Record 18 of Set 10 | kitimat
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | namie
# Processing Record 21 of Set 10 | kotido
# Processing Record 22 of Set 10 | faanui
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | manaus
# Processing Record 25 of Set 10 | talnakh
# Processing Record 26 of Set 10 | akyab
# Processing Record 27 of Set 10 | santa maria
# Processing Record 28 of Set 10 | sao raimundo das mangabeiras
# Processing Record 29 of Set 10 | tovste
# Processing Record 30 of Set 10 | baykit
# Processing Record 31 of Set 10 | porto nacional
# Processing Record 32 of Set 10 | aksha
# Processing Record 33 of Set 10 | mumford
# Processing Record 34 of Set 10 | kilrush
# Processing Record 35 of Set 10 | cedar city
# Processing Record 36 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 37 of Set 10 | fandriana
# Processing Record 38 of Set 10 | saint-denis
# Processing Record 39 of Set 10 | asilah
# Processing Record 40 of Set 10 | san quintin
# Processing Record 41 of Set 10 | hay river
# Processing Record 42 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 10 | yuci
# Processing Record 44 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 45 of Set 10 | lakeside
# Processing Record 46 of Set 10 | yulara
# Processing Record 47 of Set 10 | novosergiyevka
# Processing Record 48 of Set 10 | ramanuj ganj
# Processing Record 49 of Set 10 | inta
# Processing Record 0 of Set 11 | hoquiam
# Processing Record 1 of Set 11 | abha
# Processing Record 2 of Set 11 | seymchan
# Processing Record 3 of Set 11 | carson city
# Processing Record 4 of Set 11 | hambantota
# Processing Record 5 of Set 11 | alofi
# Processing Record 6 of Set 11 | pucallpa
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | vostochnyy
# Processing Record 9 of Set 11 | kawalu
# Processing Record 10 of Set 11 | umm kaddadah
# Processing Record 11 of Set 11 | sayyan
# Processing Record 12 of Set 11 | carauari
# Processing Record 13 of Set 11 | buta
# Processing Record 14 of Set 11 | simbahan
# Processing Record 15 of Set 11 | mareeba
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | kloulklubed
# Processing Record 18 of Set 11 | lokoja
# Processing Record 19 of Set 11 | baghdad
# Processing Record 20 of Set 11 | disna
# Processing Record 21 of Set 11 | boca do acre
# Processing Record 22 of Set 11 | singapore
# Processing Record 23 of Set 11 | sergeyevka
# Processing Record 24 of Set 11 | lakeway
# Processing Record 25 of Set 11 | vanimo
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | grafton
# Processing Record 29 of Set 11 | xining
# Processing Record 30 of Set 11 | kalabo
# Processing Record 31 of Set 11 | tezu
# Processing Record 32 of Set 11 | zinder
# Processing Record 33 of Set 11 | washington
# Processing Record 34 of Set 11 | clarence town
# Processing Record 35 of Set 11 | orthez
# Processing Record 36 of Set 11 | quibor
# Processing Record 37 of Set 11 | leirvik
# Processing Record 38 of Set 11 | pandan
# Processing Record 39 of Set 11 | road town
# Processing Record 40 of Set 11 | la baule-escoublac
# Processing Record 41 of Set 11 | san patricio
# Processing Record 42 of Set 11 | najran
# Processing Record 43 of Set 11 | lovington
# Processing Record 44 of Set 11 | amberley
# Processing Record 45 of Set 11 | iranshahr
# Processing Record 46 of Set 11 | lloydminster
# Processing Record 47 of Set 11 | mabaruma
# Processing Record 48 of Set 11 | le port
# Processing Record 49 of Set 11 | horsham
# Processing Record 0 of Set 12 | leningradskiy
# Processing Record 1 of Set 12 | podporozhye
# Processing Record 2 of Set 12 | kaitangata
# Processing Record 3 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 4 of Set 12 | sola
# Processing Record 5 of Set 12 | foster city
# Processing Record 6 of Set 12 | sao felix do xingu
# Processing Record 7 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 8 of Set 12 | dhamtari
# Processing Record 9 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 12 | otjiwarongo
# Processing Record 11 of Set 12 | banjar
# Processing Record 12 of Set 12 | pacific grove
# Processing Record 13 of Set 12 | geraldton
# Processing Record 14 of Set 12 | aykhal
# Processing Record 15 of Set 12 | villaviciosa
# Processing Record 16 of Set 12 | watrous
# Processing Record 17 of Set 12 | antigonish
# Processing Record 18 of Set 12 | micheweni
# Processing Record 19 of Set 12 | eastleigh
# Processing Record 20 of Set 12 | mpulungu
# Processing Record 21 of Set 12 | stralsund
# Processing Record 22 of Set 12 | bitung
# Processing Record 23 of Set 12 | mount isa
# Processing Record 24 of Set 12 | phan thiet
# Processing Record 25 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 12 | leh
# Processing Record 27 of Set 12 | gidam
# Processing Record 28 of Set 12 | chiredzi
# Processing Record 29 of Set 12 | ola
# Processing Record 30 of Set 12 | lelystad
# Processing Record 31 of Set 12 | hue
# Processing Record 32 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 12 | north vanlaiphai
# Processing Record 34 of Set 12 | mogadishu
# Processing Record 35 of Set 12 | pacifica
# Processing Record 36 of Set 12 | bemidji
# Processing Record 37 of Set 12 | mapiripan
# Processing Record 38 of Set 12 | gonbad-e qabus
# Processing Record 39 of Set 12 | alekseyevsk
# Processing Record 40 of Set 12 | sur
# Processing Record 41 of Set 12 | den helder
# Processing Record 42 of Set 12 | jiaozuo
# Processing Record 43 of Set 12 | pozo colorado
# Processing Record 44 of Set 12 | atambua
# Processing Record 45 of Set 12 | jinchang
# Processing Record 46 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 12 | nuevo progreso
# Processing Record 48 of Set 12 | golden
# Processing Record 49 of Set 12 | hervey bay
# Processing Record 0 of Set 13 | brenham
# Processing Record 1 of Set 13 | dali
# Processing Record 2 of Set 13 | korhogo
# Processing Record 3 of Set 13 | shakawe
# Processing Record 4 of Set 13 | sungaipenuh
# Processing Record 5 of Set 13 | gurlan
# Processing Record 6 of Set 13 | zhob
# Processing Record 7 of Set 13 | griffith
# Processing Record 8 of Set 13 | astara
# Processing Record 9 of Set 13 | campbell river
# Processing Record 10 of Set 13 | carbonear
# Processing Record 11 of Set 13 | udachnyy
# Processing Record 12 of Set 13 | camargo
# Processing Record 13 of Set 13 | dunedin
# Processing Record 14 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 15 of Set 13 | ha giang
# Processing Record 16 of Set 13 | rocha
# Processing Record 17 of Set 13 | capuluan
# Processing Record 18 of Set 13 | jaque
# Processing Record 19 of Set 13 | acapulco
# Processing Record 20 of Set 13 | tha mai
# Processing Record 21 of Set 13 | ageyevo
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 13 | ryotsu
# Processing Record 25 of Set 13 | lhuntshi
# City not found. Skipping...
# Processing Record 26 of Set 13 | sumbawanga
# Processing Record 27 of Set 13 | noceto
# Processing Record 28 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 13 | nisia floresta
# Processing Record 30 of Set 13 | newport
# Processing Record 31 of Set 13 | deputatskiy
# Processing Record 32 of Set 13 | coihaique
# Processing Record 33 of Set 13 | port augusta
# Processing Record 34 of Set 13 | hecun
# Processing Record 35 of Set 13 | mugumu
# Processing Record 36 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 37 of Set 13 | elmira
# Processing Record 38 of Set 13 | evensk
# Processing Record 39 of Set 13 | bintulu
# Processing Record 40 of Set 13 | margate
# Processing Record 41 of Set 13 | gobabis
# Processing Record 42 of Set 13 | port-cartier
# Processing Record 43 of Set 13 | oksfjord
# Processing Record 44 of Set 13 | kvarkeno
# Processing Record 45 of Set 13 | jumla
# Processing Record 46 of Set 13 | torbay
# Processing Record 47 of Set 13 | sinnamary
# Processing Record 48 of Set 13 | deer lake
# Processing Record 49 of Set 13 | dhekiajuli
# Processing Record 0 of Set 14 | anito
# Processing Record 1 of Set 14 | hihya
# Processing Record 2 of Set 14 | kokopo
# Processing Record 3 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 4 of Set 14 | emba
# Processing Record 5 of Set 14 | sao lourenco do oeste
# Processing Record 6 of Set 14 | oxelosund
# Processing Record 7 of Set 14 | tupancireta
# Processing Record 8 of Set 14 | likasi
# Processing Record 9 of Set 14 | kyshtovka
# Processing Record 10 of Set 14 | kuldiga
# Processing Record 11 of Set 14 | corat
# Processing Record 12 of Set 14 | indianola
# Processing Record 13 of Set 14 | sharjah
# Processing Record 14 of Set 14 | mecca
# Processing Record 15 of Set 14 | nizwa
# Processing Record 16 of Set 14 | unguia
# Processing Record 17 of Set 14 | artigas
# Processing Record 18 of Set 14 | broken hill
# Processing Record 19 of Set 14 | tessalit
# Processing Record 20 of Set 14 | afonso bezerra
# Processing Record 21 of Set 14 | taoudenni
# Processing Record 22 of Set 14 | dwarka
# Processing Record 23 of Set 14 | boffa
# Processing Record 24 of Set 14 | hargeysa
# Processing Record 25 of Set 14 | nador
# Processing Record 26 of Set 14 | laguna
# Processing Record 27 of Set 14 | matinhos
# Processing Record 28 of Set 14 | fecamp
# Processing Record 29 of Set 14 | longkou
# Processing Record 30 of Set 14 | alice springs
# Processing Record 31 of Set 14 | san policarpo
# Processing Record 32 of Set 14 | gwadar
# Processing Record 33 of Set 14 | bontang
# Processing Record 34 of Set 14 | the valley
# Processing Record 35 of Set 14 | fort nelson
# Processing Record 36 of Set 14 | ajaccio
# Processing Record 37 of Set 14 | keningau
# Processing Record 38 of Set 14 | rio verde de mato grosso
# Processing Record 39 of Set 14 | san ramon
# Processing Record 40 of Set 14 | ritchie
# Processing Record 41 of Set 14 | gaoua
# Processing Record 42 of Set 14 | silver city
# Processing Record 43 of Set 14 | conceicao do araguaia
# Processing Record 44 of Set 14 | matagami
# Processing Record 45 of Set 14 | ciudad del maiz
# Processing Record 46 of Set 14 | contamana
# Processing Record 47 of Set 14 | taitung
# Processing Record 48 of Set 14 | abrau-dyurso
# Processing Record 49 of Set 14 | plainview
# Processing Record 0 of Set 15 | inhambane
# Processing Record 1 of Set 15 | yarim
# Processing Record 2 of Set 15 | vila velha
# Processing Record 3 of Set 15 | mpika
# Processing Record 4 of Set 15 | vaitape
# Processing Record 5 of Set 15 | manakara
# Processing Record 6 of Set 15 | douglas
# Processing Record 7 of Set 15 | colac
# Processing Record 8 of Set 15 | uppsala
# Processing Record 9 of Set 15 | hauterive
# Processing Record 10 of Set 15 | pelym
# Processing Record 11 of Set 15 | abu zabad
# Processing Record 12 of Set 15 | le havre
# Processing Record 13 of Set 15 | kaliua
# Processing Record 14 of Set 15 | raudeberg
# Processing Record 15 of Set 15 | kang
# Processing Record 16 of Set 15 | vedaranniyam
# City not found. Skipping...
# Processing Record 17 of Set 15 | severo-yeniseyskiy
# Processing Record 18 of Set 15 | brawley
# Processing Record 19 of Set 15 | kushiro
# Processing Record 20 of Set 15 | turinsk
# Processing Record 21 of Set 15 | pochutla
# Processing Record 22 of Set 15 | straumen
# Processing Record 23 of Set 15 | katherine
# Processing Record 24 of Set 15 | canete
# Processing Record 25 of Set 15 | samarai
# Processing Record 26 of Set 15 | lethem
# Processing Record 27 of Set 15 | ransang
# Processing Record 28 of Set 15 | shelburne
# Processing Record 29 of Set 15 | urfa
# City not found. Skipping...
# Processing Record 30 of Set 15 | sirpur
# Processing Record 31 of Set 15 | noumea
# Processing Record 32 of Set 15 | viedma
# Processing Record 33 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of Set 15 | yatou
# Processing Record 35 of Set 15 | muros
# Processing Record 36 of Set 15 | dori
# Processing Record 37 of Set 15 | tarakan
# Processing Record 38 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 15 | oum hadjer
# Processing Record 40 of Set 15 | cabra
# Processing Record 41 of Set 15 | kathmandu
# Processing Record 42 of Set 15 | excelsior springs
# Processing Record 43 of Set 15 | kaeo
# Processing Record 44 of Set 15 | avera
# Processing Record 45 of Set 15 | asosa
# Processing Record 46 of Set 15 | tuy hoa
# Processing Record 47 of Set 15 | grand-santi
# Processing Record 48 of Set 15 | cabedelo
# Processing Record 49 of Set 15 | mazatlan
# Processing Record 0 of Set 16 | itapuranga
# Processing Record 1 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 16 | christchurch
# Processing Record 3 of Set 16 | vila
# Processing Record 4 of Set 16 | san ramon de la nueva oran
# Processing Record 5 of Set 16 | canico
# Processing Record 6 of Set 16 | chimbote
# Processing Record 7 of Set 16 | suwannaphum
# Processing Record 8 of Set 16 | iqaluit
# Processing Record 9 of Set 16 | jieshi
# Processing Record 10 of Set 16 | amga
# Processing Record 11 of Set 16 | porto novo
# Processing Record 12 of Set 16 | fayaoue
# Processing Record 13 of Set 16 | ancud
# Processing Record 14 of Set 16 | karpathos
# Processing Record 15 of Set 16 | laem sing
# Processing Record 16 of Set 16 | tiznit
# Processing Record 17 of Set 16 | ontario
# Processing Record 18 of Set 16 | pueblo nuevo
# Processing Record 19 of Set 16 | sambava
# Processing Record 20 of Set 16 | polunochnoye
# Processing Record 21 of Set 16 | ayan
# Processing Record 22 of Set 16 | taksimo
# Processing Record 23 of Set 16 | balkhash
# Processing Record 24 of Set 16 | soyo
# Processing Record 25 of Set 16 | port hardy
# Processing Record 26 of Set 16 | ayame
# Processing Record 27 of Set 16 | san andres
# Processing Record 28 of Set 16 | varhaug
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len (city_data)
# Out:
# 726

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    bredasdorp -34.5322   20.0403     19.42        86          64
# 1     kyrylivka  46.3759   35.3675     -2.07        85          97
# 2    naryan-mar  67.6713   53.0870     -4.78        92         100
# 3   provideniya  64.3833 -173.3000    -24.80        64          40
# 4       husavik  66.0449  -17.3389     -1.94        86         100
# 5       ushuaia -54.8000  -68.3000      3.81        81         100
# 6       rikitea -23.1203 -134.9692     26.27        70         100
# 7      flinders -34.5833  150.8552     29.54        61          85
# 8  capitan bado -23.2667  -55.5333     21.48        88         100
# 9     carnarvon -24.8667  113.6333     26.04        56           0
#
#    Wind Speed Country        Date
# 0        7.88      ZA  1676516299
# 1        5.08      UA  1676516300
# 2        8.96      RU  1676516301
# 3        6.00      RU  1676516302
# 4        3.84      IS  1676516302
# 5        7.72      AR  1676516303
# 6        2.62      PF  1676516304
# 7        2.24      AU  1676516304
# 8        2.05      PY  1676516304
# 9        7.44      AU  1676516180

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_name = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# Recreate the DataFrame by using the new column order
df = city_data_df.reindex(columns= new_column_name)

# Display sample data
print (df)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     bredasdorp      ZA -34.5322   20.0403     19.42        86          64
# 1      kyrylivka      UA  46.3759   35.3675     -2.07        85          97
# 2     naryan-mar      RU  67.6713   53.0870     -4.78        92         100
# 3    provideniya      RU  64.3833 -173.3000    -24.80        64          40
# 4        husavik      IS  66.0449  -17.3389     -1.94        86         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 721         soyo      AO  -6.1349   12.3689     25.83        82          94
# 722   port hardy      CA  50.6996 -127.4199      4.10        87         100
# 723        ayame      CI   5.6083   -3.1563     25.25        87          87
# 724   san andres      CO  12.5847  -81.7006     27.01        74          20
# 725      varhaug      NO  58.6147    5.6457      6.75        93          98
#
#      Wind Speed
# 0          7.88
# 1          5.08
# 2          8.96
# 3          6.00
# 4          3.84
# ..          ...
# 721        0.67
# 722       10.80
# 723        1.22
# 724        7.20
# 725        4.44
#
# [726 rows x 8 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name = "WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name)
